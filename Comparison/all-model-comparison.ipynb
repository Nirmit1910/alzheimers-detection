# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 

# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# # Comparison of various metrics of Transfer Learning Models

# %%
#Model names
model_names = ['VGG16', 'VGG19','Resnet', 'MobileNetV2', 'InceptionV3', 'DenseNet169','EfficientNetb0','CNN']


#Various Metrics
test_loss = [0.193, 0.279, 0.324, 0.941, 0.426, 0.304, 0.110, 0.035]
test_accuracy = [0.927, 0.897, 0.900, 0.581, 0.858, 0.896, 0.962, 0.991]
test_auc = [0.993, 0.986, 0.982, 0.842, 0.974, 0.981, 0.997, 0.999]
test_precision = [0.928, 0.898, 0.903, 0.620, 0.867, 0.899, 0.964, 0.991]
test_recall = [0.924, 0.891, 0.897, 0.483, 0.852, 0.889, 0.962, 0.991]

# %%
# Set the style of the plots
plt.style.use('ggplot')

# %%
plt.figure(figsize=(15, 6))

# Bar plot for accuracy
colors = ['skyblue', 'lightgreen', 'salmon', 'gold', 'plum', 'teal', 'tomato','cyan']
plt.bar(model_names, test_accuracy,color=colors)
plt.plot(model_names, test_accuracy,marker='o',color='red')

# Adding labels and title
plt.xlabel('Model Names',fontsize=12, fontweight='bold')
plt.ylabel('Accuracy',fontsize=12, fontweight='bold')
plt.title('Bar Plot',fontsize=12, fontweight='bold')

plt.grid(axis='y', linestyle='--', alpha=0.5)

label_offset = max(test_accuracy) * 0.005

for i, v in enumerate(test_accuracy):
    plt.text(i,  v + label_offset,str(round(v,2)), ha='center', va='bottom', fontsize=10, fontweight='bold')

# Display the plot
plt.show()

plt.savefig('/kaggle/working/plot.png')

# %%
plt.figure(figsize=(15, 6))

# Bar plot for loss
colors = ['skyblue', 'lightgreen', 'salmon', 'gold', 'plum', 'teal', 'tomato','cyan']
plt.bar(model_names, test_loss,color=colors)
plt.plot(model_names, test_loss,marker='o',color='red')

# Adding labels and title
plt.xlabel('Model Names',fontsize=12, fontweight='bold')
plt.ylabel('Loss',fontsize=12, fontweight='bold')
plt.title('Loss Plot',fontsize=12, fontweight='bold')

plt.grid(axis='y', linestyle='--', alpha=0.5)

label_offset = max(test_loss) * 0.005

for i, v in enumerate(test_loss):
    plt.text(i,  v + label_offset,str(round(v,2)), ha='center', va='bottom', fontsize=10, fontweight='bold')

# Display the plot
plt.show()

# Show the plot
plt.show()

# %%
plt.figure(figsize=(15, 6))

# Bar plot for loss
colors = ['skyblue', 'lightgreen', 'salmon', 'gold', 'plum', 'teal', 'tomato','cyan']
plt.bar(model_names, test_auc,color=colors)
plt.plot(model_names, test_auc,marker='o',color='red')

# Adding labels and title
plt.xlabel('Model Names',fontsize=12, fontweight='bold')
plt.ylabel('AUC',fontsize=12, fontweight='bold')
plt.title('AUC Plot',fontsize=12, fontweight='bold')

plt.grid(axis='y', linestyle='--', alpha=0.5)

label_offset = max(test_auc) * 0.005

for i, v in enumerate(test_auc):
    plt.text(i,  v + label_offset,str(round(v,2)), ha='center', va='bottom', fontsize=10, fontweight='bold')

# Display the plot
plt.show()

# Show the plot
plt.show()

# %%
plt.figure(figsize=(15, 6))

# Bar plot for loss
colors = ['skyblue', 'lightgreen', 'salmon', 'gold', 'plum', 'teal', 'tomato','cyan']
plt.bar(model_names, test_precision ,color=colors)
plt.plot(model_names, test_precision,marker='o',color='red')

# Adding labels and title
plt.xlabel('Model Names',fontsize=12, fontweight='bold')
plt.ylabel('Precision',fontsize=12, fontweight='bold')
plt.title('Precision Plot',fontsize=12, fontweight='bold')

plt.grid(axis='y', linestyle='--', alpha=0.5)

label_offset = max(test_precision) * 0.005

for i, v in enumerate(test_precision):
    plt.text(i,  v + label_offset,str(round(v,2)), ha='center', va='bottom', fontsize=10, fontweight='bold')

# Display the plot
plt.show()

# Show the plot
plt.show()

# %%
plt.figure(figsize=(15, 6))

# Bar plot for loss
colors = ['skyblue', 'lightgreen', 'salmon', 'gold', 'plum', 'teal', 'tomato','cyan']
plt.bar(model_names, test_recall ,color=colors)
plt.plot(model_names, test_recall,marker='o',color='red')


# Adding labels and title
plt.xlabel('Model Names',fontsize=12, fontweight='bold')
plt.ylabel('Recall',fontsize=12, fontweight='bold')
plt.title('Recall Plot',fontsize=12, fontweight='bold')

plt.grid(axis='y', linestyle='--', alpha=0.5)

label_offset = max(test_recall) * 0.005

for i, v in enumerate(test_recall):
    plt.text(i,  v + label_offset,str(round(v,2)), ha='center', va='bottom', fontsize=10, fontweight='bold')

# Display the plot
plt.show()

# Show the plot
plt.show()

# %% [markdown]
# # Comparison of various Machine Learning Models

# %%
data = {'models': ["Logistic Regression","SVM","Random Forest"], 
        'accuracy': [0.75,0.99,0.71],
        'precision':[0.81,0.99,0.64],
        'recall':[0.73,0.99,0.42],
       }

# pass column names in the columns parameter 
df = pd.DataFrame.from_dict(data)
df
# Out:
#                 models  accuracy  precision  recall
# 0  Logistic Regression      0.75       0.81    0.73
# 1                  SVM      0.99       0.99    0.99
# 2        Random Forest      0.71       0.64    0.42

# %%
plt.figure(figsize=(10, 6))

# Bar plot for loss
colors = ['skyblue', 'lightgreen', 'salmon']
plt.bar(df['models'], df['accuracy'] ,color=colors)
plt.plot(df['models'], df['accuracy'],marker='o',color='red')

# Adding labels and title
plt.xlabel('Model Names',fontsize=12, fontweight='bold')
plt.ylabel('Accuarcy',fontsize=12, fontweight='bold')
plt.title('Accuarcy Plot',fontsize=12, fontweight='bold')

plt.grid(axis='y', linestyle='--', alpha=0.5)

label_offset = max(df['accuracy']) * 0.005

for i, v in enumerate(df['accuracy']):
    plt.text(i,  v + label_offset,str(round(v,2)), ha='center', va='bottom', fontsize=10, fontweight='bold')

# Display the plot
plt.show()

# Show the plot
plt.show()

# %%
plt.figure(figsize=(10, 6))

# Bar plot for loss
colors = ['skyblue', 'lightgreen', 'salmon']
plt.bar(df['models'], df['precision'] ,color=colors)
plt.plot(df['models'], df['precision'],marker='o',color='red')

# Adding labels and title
plt.xlabel('Model Names',fontsize=12, fontweight='bold')
plt.ylabel('Precision',fontsize=12, fontweight='bold')
plt.title('Precision Plot',fontsize=12, fontweight='bold')

plt.grid(axis='y', linestyle='--', alpha=0.5)

label_offset = max(df['precision']) * 0.005

for i, v in enumerate(df['precision']):
    plt.text(i,  v + label_offset,str(round(v,2)), ha='center', va='bottom', fontsize=10, fontweight='bold')

# Display the plot
plt.show()

# Show the plot
plt.show()

# %%
plt.figure(figsize=(10, 6))

# Bar plot for loss
colors = ['skyblue', 'lightgreen', 'salmon']
plt.bar(df['models'], df['recall'] ,color=colors)
plt.plot(df['models'], df['recall'],marker='o',color='red')

# Adding labels and title
plt.xlabel('Model Names',fontsize=12, fontweight='bold')
plt.ylabel('Recall',fontsize=12, fontweight='bold')
plt.title('Recall Plot',fontsize=12, fontweight='bold')

plt.grid(axis='y', linestyle='--', alpha=0.5)

label_offset = max(df['recall']) * 0.005

for i, v in enumerate(df['recall']):
    plt.text(i,  v + label_offset,str(round(v,2)), ha='center', va='bottom', fontsize=10, fontweight='bold')

# Display the plot
plt.show()

# Show the plot
plt.show()

# %%
combined_names=[i for i in model_names]

# %%
[combined_names.append(i) for i in df.models]
# Out:
# [None, None, None]

# %%
combined_acc=[i for i in test_accuracy]

# %%
[combined_acc.append(i) for i in df.accuracy]
# Out:
# [None, None, None]

# %%
plt.figure(figsize=(17, 6))

# Bar plot for loss
colors = ['skyblue', 'lightgreen', 'salmon', 'gold', 'plum', 'teal', 'tomato', 'lime', 'indigo', 'coral','yellow']
plt.bar(combined_names, combined_acc ,color=colors)
plt.plot(combined_names, combined_acc,marker='o',color='red')


# Adding labels and title
plt.xlabel('Model Names',fontsize=12, fontweight='bold')
plt.ylabel('Accuracy',fontsize=12, fontweight='bold')
plt.title('Recall Plot',fontsize=12, fontweight='bold')

plt.grid(axis='y', linestyle='--', alpha=0.5)

label_offset = max(combined_acc) * 0.005

for i, v in enumerate(combined_acc):
    plt.text(i,  v + label_offset,str(round(v,2)), ha='center', va='bottom', fontsize=10, fontweight='bold')

# Display the plot
plt.show()

# Show the plot
plt.show()

# %%
results = {
    'Model': ['VGG16', 'VGG19', 'Resnet', 'MobileNetV2', 'InceptionV3', 'DenseNet169', 'EfficientNetB0', 'CNN'],
    'Test Loss': [0.19338423013687134, 0.2789330780506134, 0.3243464231491089, 0.941156804561615, 0.42555341124534607, 0.3042619824409485, 0.11009451001882553, 0.035189464688301086],
    'Test Accuracy': [0.926791250705719, 0.8971962332725525, 0.9003115296363831, 0.5809968709945679, 0.8582554459571838, 0.895638644695282, 0.9624999761581421, 0.9906542301177979],
    'Test AUC': [0.9927954077720642, 0.9861191511154175, 0.9816888570785522, 0.8419889211654663, 0.9738049507141113, 0.9813541769981384, 0.9973616003990173, 0.9997194409370422],
    'Test Precision': [0.928012490272522, 0.8979591727256775, 0.9028213024139404, 0.6200000047683716, 0.8668779730796814, 0.8992125988006592, 0.964006245136261, 0.9906542301177979],
    'Test Recall': [0.9236760139465332, 0.8909657597541809, 0.8971962332725525, 0.4828660488128662, 0.8520249128341675, 0.8894081115722656, 0.9624999761581421, 0.9906542301177979]
}

# Create a dataframe
df = pd.DataFrame(results)

# %%
df
# Out:
#             Model  Test Loss  Test Accuracy  Test AUC  Test Precision  \
# 0           VGG16   0.193384       0.926791  0.992795        0.928012
# 1           VGG19   0.278933       0.897196  0.986119        0.897959
# 2          Resnet   0.324346       0.900312  0.981689        0.902821
# 3     MobileNetV2   0.941157       0.580997  0.841989        0.620000
# 4     InceptionV3   0.425553       0.858255  0.973805        0.866878
# 5     DenseNet169   0.304262       0.895639  0.981354        0.899213
# 6  EfficientNetB0   0.110095       0.962500  0.997362        0.964006
# 7             CNN   0.035189       0.990654  0.999719        0.990654
#
#    Test Recall
# 0     0.923676
# 1     0.890966
# 2     0.897196
# 3     0.482866
# 4     0.852025
# 5     0.889408
# 6     0.962500
# 7     0.990654
